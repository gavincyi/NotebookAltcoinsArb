# %%
import requests
import re
import pandas as pd
import time
from bs4 import BeautifulSoup

# %% [markdown]
# # Get all the symbols

# %%
response = requests.get("https://coinmarketcap.com/currencies/")
soup = BeautifulSoup(response.text, 'html.parser')

# %%
main_table = [t for t in soup.find_all('table') if t.has_attr('id') and t['id'] == 'currencies']
assert len(main_table) == 1, "Only one main table"
main_table = main_table[0]

# %%
coins = [t for t in main_table.find_all('tr') if t.has_attr('id')]
coin_aliases = [re.search("\/currencies\/(.*)\/", t.find_all('a')[0]['href']).group(1) for t in coins]
coin_aliases
# Out:
# ['bitcoin',
#  'ethereum',
#  'ripple',
#  'litecoin',
#  'ethereum-classic',
#  'dash',
#  'nem',
#  'monero',
#  'iota',
#  'stratis',
#  'bitconnect',
#  'zcash',
#  'bitshares',
#  'antshares',
#  'bytecoin-bcn',
#  'steem',
#  'qtum',
#  'waves',
#  'stellar',
#  'siacoin',
#  'dogecoin',
#  'lisk',
#  'byteball',
#  'factom',
#  'decred',
#  'komodo',
#  'digibyte',
#  'gamecredits',
#  'pivx',
#  'nxt',
#  'bancor',
#  'lykke',
#  'chaincoin',
#  'bitcoindark',
#  'leocoin',
#  'decent',
#  'peercoin',
#  'syscoin',
#  'emercoin',
#  'nexus',
#  'ark',
#  'ubiq',
#  'verge',
#  'reddcoin',
#  'namecoin',
#  'monacoin',
#  'gulden',
#  'asch',
#  'peerplays-ppy',
#  'cloakcoin',
#  'e-dinar-coin',
#  'daxxcoin',
#  'sibcoin',
#  'counterparty',
#  'skycoin',
#  'blocknet',
#  'library-credit',
#  'bitbay',
#  'omni',
#  'ybcoin',
#  'potcoin',
#  'zcoin',
#  'mooncoin',
#  'blackcoin',
#  'viacoin',
#  'burst',
#  'crown',
#  'faircoin',
#  'dubaicoin-dbix',
#  'vertcoin',
#  'groestlcoin',
#  'iocoin',
#  'firstcoin',
#  'golos',
#  'expanse',
#  'elastic',
#  'nav-coin',
#  'novacoin',
#  'salus',
#  'digitalnote',
#  'gridcoin',
#  'e-coin',
#  'earthcoin',
#  'voxels',
#  'monetaryunit',
#  'mysterium',
#  'neoscoin',
#  'ion',
#  'luckchain',
#  'bitcoin-plus',
#  'rubycoin',
#  'heat-ledger',
#  'radium',
#  'energycoin',
#  'spreadcoin',
#  'xtrabytes',
#  'clams',
#  'unobtanium',
#  'feathercoin',
#  'dnotes']

# %% [markdown]
# # Get all the market prices

# %%
# Initialize variables
LEVEL=5
NUM_OF_COINS=50

# %%
def get_pair_info(tr_text):
    """
    Get pair info from html text of <tr>
    """
    tds = tr_text.find_all('td')
    exchange = tds[1].text
    pair = tds[2].text
    volume = float(tds[3].find('span')['data-usd']) if tds[3].find('span')['data-usd'] != '?' else 0
    price = float(tds[4].find('span')['data-usd']) if tds[4].find('span')['data-usd'] != '?' else 0
    share = float(tds[5].text[0:-1])
    time = tds[6].text

    return exchange, pair, volume, price, share, time

# %%
def get_records(coin_alias):
    """
    Get the highest and lowest 5 prices among all exchanges.
    """
    # Get the market html
    coin_market_ret = requests.get("https://coinmarketcap.com/currencies/%s/#markets" % coin_alias)
    assert coin_market_ret.status_code == 200, "Status code (%d) is not 200.\n%s" % (coin_market_ret.status_code, coin_market_ret.text)
    coin_market_soup = BeautifulSoup(coin_market_ret.text, 'html.parser')
    coin_table = [t for t in coin_market_soup.find_all('table') if t.has_attr('id') and t['id'] == 'markets-table']
    assert len(coin_table) == 1, "Only one main table"
    coin_table = coin_table[0]
    # Get all the records
    coin_records = coin_table.find_all('tr')
    records = pd.DataFrame(columns=['exchange', 'pair', 'volume', 'price', 'share', 'last_updated'],
                           data=[get_pair_info(t) for t in coin_records 
                                 if len(t.find_all('td')) > 0])
    # Take only recent records
    records = records[(records['last_updated'] == "Recently") & (records['price'] > 0)]
    return records

# %%
coin_records = {}
for coin_alias in coin_aliases[0:NUM_OF_COINS]:
    coin_records[coin_alias] = get_records(coin_alias)
    time.sleep(5)

# %%
arb_pairs = pd.DataFrame(columns=(["h%d" % (t+1) for t in range(0,LEVEL)]
                                  +["l%d" % (t+1) for t in range(0,LEVEL)]
                                  +["pd%d" % (t+1) for t in range(0,LEVEL)]))
for coin_alias in coin_aliases[0:NUM_OF_COINS]:
    records = coin_records[coin_alias]
    highest = records.sort_values('price', ascending=False).head(LEVEL)
    lowest = records.sort_values('price').head(LEVEL)
    highest_desc = highest.apply(lambda x: "%s (%.6f)" % (x["exchange"], x["price"]), axis=1)
    lowest_desc = lowest.apply(lambda x: "%s (%.6f)" % (x["exchange"], x["price"]), axis=1)
    pd = records.sort_values('price', ascending=False).head(LEVEL)['price'].values
    pd /= records.sort_values('price').head(LEVEL)['price'].values
    pd = (pd - 1) * 100
    highest_desc = (highest_desc.tolist() + ['???'] * LEVEL)[0:LEVEL]
    lowest_desc = (lowest_desc.tolist() + ['???'] * LEVEL)[0:LEVEL]
    pd = (pd.tolist() + [0] * LEVEL)[0:LEVEL]
    arb_pairs.loc[coin_alias] = highest_desc + lowest_desc + pd
    time.sleep(5)
arb_pairs
# Out:
#                                            h1                          h2  \
# bitcoin                Poloniex (3990.580000)         xBTCe (2780.270000)
# ethereum              Decentrex (7608.260000)   Novaexchange (628.305000)
# ripple                   BTCXIndia (0.188233)       Cryptomate (0.182348)
# litecoin           Cryptopia (1894970.000000)  CoinGather (842209.000000)
# ethereum-classic            C-CEX (18.950000)           USD X (16.992900)
# dash               Novaexchange (1278.790000)   CoinExchange (217.951000)
# nem                      Cryptopia (0.182777)       LiteBit.eu (0.115635)
# monero               SouthXchange (35.000000)      Cryptomate (34.803100)
# iota                      Bitfinex (0.163295)         Bitfinex (0.162569)
# stratis                  Cryptopia (4.763050)     SouthXchange (3.603900)
# bitconnect          Novaexchange (127.642000)    BCC Exchange (49.595400)
# zcash                      USD X (317.235000)      Cryptopia (288.844000)
# bitshares         OpenLedger DEX (138.179000)   OpenLedger DEX (2.872590)
# antshares                    19800 (5.299540)             Jubi (5.182980)
# bytecoin-bcn              Poloniex (0.001289)         Poloniex (0.001271)
# steem               OpenLedger DEX (1.512000)   OpenLedger DEX (1.485880)
# qtum                          BTER (3.983510)          Yuanbao (3.977600)
# waves               OpenLedger DEX (4.036700)            Tidex (3.980130)
# stellar                      BTC38 (0.017527)        RippleFox (0.017421)
# siacoin                  Cryptopia (0.007589)            Yunbi (0.006326)
# dogecoin                Cryptopia (79.549600)        Cryptopia (4.474930)
# lisk                OpenLedger DEX (2.180800)           HitBTC (1.898640)
# byteball               Cryptopia (456.662000)      Cryptopia (396.014000)
# factom                  Cryptopia (39.041400)       Cryptopia (28.683600)
# decred                  Cryptopia (24.596100)       Bleutrade (21.514100)
# komodo                CoinExchange (1.085210)          Bittrex (0.890164)
# digibyte                    EmpoEx (0.013878)       LiteBit.eu (0.010287)
# gamecredits         OpenLedger DEX (7.340170)   OpenLedger DEX (5.000000)
# pivx                  CoinExchange (3.964440)         Livecoin (3.424900)
# nxt                          C-CEX (0.165000)            C-CEX (0.079262)
# bancor                       Tidex (1.784290)          Bittrex (1.655210)
# lykke               Lykke Exchange (0.254575)   Lykke Exchange (0.251617)
# chaincoin            Novaexchange (20.025400)        Cryptopia (3.153760)
# bitcoindark             Cryptopia (54.497400)       Bleutrade (44.459600)
# leocoin              Trade Satoshi (0.871072)            C-CEX (0.629974)
# decent                       Liqui (1.980540)          Yuanbao (1.041610)
# peercoin                     USD X (2.529330)     Bittylicious (2.026910)
# syscoin               Bittylicious (0.102930)           EmpoEx (0.099147)
# emercoin           OpenLedger DEX (18.395600)            USD X (1.545870)
# nexus                      Bittrex (0.673670)        Cryptopia (0.667028)
# ark                      Cryptopia (1.014680)       LiteBit.eu (0.374171)
# ubiq                     Cryptopia (0.803606)          Bittrex (0.749938)
# verge                 Novaexchange (0.005445)       CoinGather (0.003961)
# reddcoin                CoinGather (0.001289)    Trade Satoshi (0.001209)
# namecoin               BX Thailand (3.566600)     Bittylicious (2.605990)
# monacoin                      Zaif (0.471846)          Bittrex (0.454162)
# gulden                       YoBit (0.153786)     Novaexchange (0.082097)
# asch                    Crypto Dao (0.594764)             Jubi (0.309828)
# peerplays-ppy           Crypto Dao (8.326700)         Livecoin (5.622980)
# cloakcoin                Mercatox (57.097400)       Cryptopia (10.756400)
#
#                                                        h3  \
# bitcoin                               C-CEX (2626.400000)
# ethereum                          EtherDelta (604.415000)
# ripple                                    BTER (0.179491)
# litecoin                      Novaexchange (89498.600000)
# ethereum-classic                  BTC Markets (16.362600)
# dash                            Bittylicious (209.673000)
# nem                                       Zaif (0.115013)
# monero                              Bitsquare (32.973700)
# iota                             IOTA Exchange (0.162569)
# stratis                           Bittylicious (3.368150)
# bitconnect                           Livecoin (49.118000)
# zcash                                Bitlish (254.034000)
# bitshares                                YoBit (0.267750)
# antshares                              Yuanbao (5.150530)
# bytecoin-bcn                            HitBTC (0.001106)
# steem                           OpenLedger DEX (1.293110)
# qtum                                     Yunbi (3.948240)
# waves             Waves Decentralized Exchange (3.837900)
# stellar                      Bitcoin Indonesia (0.017387)
# siacoin                                Bittrex (0.006253)
# dogecoin                         Trade Satoshi (0.053992)
# lisk                                    BitBay (1.708730)
# byteball                             Bittrex (376.704000)
# factom                              BTC Alpha (15.459900)
# decred                               Poloniex (19.984100)
# komodo                               Cryptopia (0.880251)
# digibyte                                 YoBit (0.010111)
# gamecredits                     OpenLedger DEX (1.898210)
# pivx                                  Livecoin (2.074630)
# nxt                               SouthXchange (0.077081)
# bancor                                 Bittrex (1.626050)
# lykke                           Lykke Exchange (0.248195)
# chaincoin                            Cryptopia (3.011390)
# bitcoindark                           Bittrex (34.099800)
# leocoin                               Livecoin (0.553727)
# decent                          OpenLedger DEX (0.693895)
# peercoin                        OpenLedger DEX (2.004970)
# syscoin                           Novaexchange (0.070182)
# emercoin                          Tux Exchange (1.011100)
# nexus                                Cryptopia (0.624662)
# ark                                  Cryptopia (0.354678)
# ubiq                                 Cryptopia (0.019523)
# verge                                    C-CEX (0.003100)
# reddcoin                          Novaexchange (0.001084)
# namecoin                        Altcoin Trader (1.917940)
# monacoin                             Bleutrade (0.453409)
# gulden                              LiteBit.eu (0.074023)
# asch                                  Biduobao (0.309828)
# peerplays-ppy                         Livecoin (5.570960)
# cloakcoin                            Cryptopia (9.760350)
#
#                                            h4                              h5  \
# bitcoin                Livecoin (2573.080000)      Bittylicious (2553.610000)
# ethereum              EtherDelta (399.989000)  CryptoDerivatives (376.716000)
# ripple                     Bitsane (0.179195)              Bitsane (0.177754)
# litecoin             Cryptopia (81510.600000)         Cryptopia (1504.410000)
# ethereum-classic      BTC Markets (16.285100)          Cryptomate (16.249600)
# dash              OpenLedger DEX (175.927000)              USD X (175.853000)
# nem                      Cryptopia (0.111701)                 BTER (0.111125)
# monero               Tux Exchange (32.513800)                BTER (31.853300)
# iota                      Bitfinex (0.161440)                             ???
# stratis                  POSWallet (3.360280)            Cryptopia (3.271200)
# bitconnect           Novaexchange (48.990700)        CoinExchange (46.987000)
# zcash                    Bitlish (252.296000)            Bitlish (208.700000)
# bitshares           OpenLedger DEX (0.162305)       OpenLedger DEX (0.158752)
# antshares                    Yunbi (5.048720)              Bittrex (5.022780)
# bytecoin-bcn                HitBTC (0.001101)            Cryptopia (0.001071)
# steem                       HitBTC (1.236360)       OpenLedger DEX (1.200640)
# qtum                          BTER (3.925440)              Allcoin (3.568780)
# waves               OpenLedger DEX (3.508570)                Tidex (2.970020)
# stellar                    Bittrex (0.017149)             Poloniex (0.017089)
# siacoin                    alcurEX (0.006245)            Cryptopia (0.006225)
# dogecoin              Novaexchange (0.041297)        Trade Satoshi (0.018411)
# lisk                        BitBay (1.600000)             Livecoin (1.432960)
# byteball                 Cryptox (376.684000)          Cryptopia (296.715000)
# factom                    alcurEX (13.179900)             Bittrex (12.834000)
# decred                  Bleutrade (19.825500)           Cryptopia (19.808400)
# komodo                   Cryptopia (0.817483)            Cryptopia (0.706739)
# digibyte                  Livecoin (0.009933)              Bittrex (0.009873)
# gamecredits                Bittrex (1.308480)                YoBit (1.308480)
# pivx                        EmpoEx (2.022200)         CoinExchange (1.782330)
# nxt                Stocks.Exchange (0.072616)   Nxt Asset Exchange (0.071463)
# bancor                      HitBTC (1.623710)               HitBTC (1.618050)
# lykke               Lykke Exchange (0.248180)       Lykke Exchange (0.248058)
# chaincoin                Cryptopia (2.931160)         Novaexchange (2.398980)
# bitcoindark              Poloniex (34.049600)           Cryptopia (33.821500)
# leocoin                 LEOxChange (0.527528)           LEOxChange (0.510723)
# decent                      HitBTC (0.642345)              Bittrex (0.633582)
# peercoin          The Rock Trading (1.743140)     The Rock Trading (1.724820)
# syscoin                      BTC38 (0.069343)             Livecoin (0.067803)
# emercoin                     xBTCe (1.009180)         CoinExchange (0.991274)
# nexus                                     ???                             ???
# ark                           COSS (0.353889)                 COSS (0.353191)
# ubiq                                      ???                             ???
# verge                   CoinGather (0.002756)            Cryptopia (0.002141)
# reddcoin                 Cryptopia (0.000965)            Bleutrade (0.000952)
# namecoin              Tux Exchange (1.784290)            Bleutrade (1.722480)
# monacoin                 Bleutrade (0.453201)                 Zaif (0.446027)
# gulden                GuldenTrader (0.070285)         CoinExchange (0.069726)
# asch                       Yuanbao (0.269278)                             ???
# peerplays-ppy                             ???                             ???
# cloakcoin                    YoBit (5.751820)           Crypto Dao (5.033670)
#
#                                             l1  \
# bitcoin               CoinGather (1410.540000)
# ethereum          CryptoDerivatives (0.121732)
# ripple                       Rippex (0.151575)
# litecoin                  Cryptopia (4.047430)
# ethereum-classic      CoinExchange (12.029400)
# dash                 OpenLedger DEX (0.122324)
# nem                            BTER (0.101646)
# monero                    Poloniex (27.174400)
# iota                       Bitfinex (0.161440)
# stratis                   Cryptopia (2.007850)
# bitconnect            CoinExchange (46.987000)
# zcash                   Cryptopia (100.220000)
# bitshares            OpenLedger DEX (0.000001)
# antshares                   Bittrex (5.022780)
# bytecoin-bcn              Cryptopia (0.001018)
# steem                      Poloniex (0.915039)
# qtum                        Allcoin (3.568780)
# waves                         Tidex (0.010524)
# stellar                   RippleFox (0.016413)
# siacoin                   Bitsquare (0.006086)
# dogecoin               Novaexchange (0.000001)
# lisk                 OpenLedger DEX (0.061774)
# byteball                Cryptopia (296.715000)
# factom                     Yuanbao (12.738400)
# decred                   Cryptopia (17.938700)
# komodo                 CoinExchange (0.640814)
# digibyte                  Cryptopia (0.008815)
# gamecredits            Novaexchange (0.509149)
# pivx                      Bitsquare (0.010507)
# nxt                 Stocks.Exchange (0.065549)
# bancor                       HitBTC (1.030010)
# lykke                Lykke Exchange (0.240739)
# chaincoin              Novaexchange (0.347469)
# bitcoindark              Bleutrade (31.555500)
# leocoin                    Livecoin (0.314387)
# decent               OpenLedger DEX (0.611620)
# peercoin                247exchange (0.286700)
# syscoin                       YoBit (0.066415)
# emercoin                   Livecoin (0.672918)
# nexus                     Cryptopia (0.624662)
# ark                       Cryptopia (0.199885)
# ubiq                      Cryptopia (0.019523)
# verge                  Novaexchange (0.001721)
# reddcoin              Trade Satoshi (0.000867)
# namecoin                247exchange (0.302834)
# monacoin                   Livecoin (0.427596)
# gulden                    Bleutrade (0.065184)
# asch                        Yuanbao (0.269278)
# peerplays-ppy              Livecoin (5.570960)
# cloakcoin                  Livecoin (3.800000)
#
#                                                           l2  \
# bitcoin           Bitcoin Growth Fund Exchange (1570.870000)
# ethereum                        CryptoDerivatives (3.737180)
# ripple                                 Mr. Ripple (0.153744)
# litecoin                               DCExchange (4.250000)
# ethereum-classic                          HitBTC (13.687800)
# dash                               OpenLedger DEX (4.850580)
# nem                                          COSS (0.107462)
# monero                                 Cryptopia (29.230000)
# iota                                     Bitfinex (0.162569)
# stratis                                  Livecoin (2.894500)
# bitconnect                          Novaexchange (48.990700)
# zcash                                  Mercatox (118.953000)
# bitshares                          OpenLedger DEX (0.006656)
# antshares                                   Yunbi (5.048720)
# bytecoin-bcn                            Cryptopia (0.001054)
# steem                                    Poloniex (0.925949)
# qtum                                         BTER (3.925440)
# waves                                       Tidex (0.488688)
# stellar                                   alcurEX (0.016614)
# siacoin                                 Cryptopia (0.006095)
# dogecoin                             Novaexchange (0.000020)
# lisk                               OpenLedger DEX (0.158602)
# byteball                                Cryptox (376.684000)
# factom                                  Poloniex (12.777700)
# decred                              Tux Exchange (19.032500)
# komodo                                  Cryptopia (0.706739)
# digibyte                                Cryptopia (0.008892)
# gamecredits                             Cryptopia (1.006800)
# pivx                                    Cryptopia (0.765211)
# nxt                                        HitBTC (0.066510)
# bancor                                 EtherDelta (1.441830)
# lykke                              Lykke Exchange (0.246719)
# chaincoin                               Cryptopia (1.998850)
# bitcoindark                             Poloniex (33.808600)
# leocoin                                LEOxChange (0.340000)
# decent                                    Bittrex (0.633582)
# peercoin                              247exchange (0.292571)
# syscoin                              Tux Exchange (0.066415)
# emercoin                                Cryptopia (0.702745)
# nexus                                   Cryptopia (0.667028)
# ark                                     Cryptopia (0.285402)
# ubiq                                      Bittrex (0.749938)
# verge                                   Cryptopia (0.001950)
# reddcoin                                Bleutrade (0.000889)
# namecoin                              247exchange (0.378444)
# monacoin                                     Zaif (0.446027)
# gulden                                  Bleutrade (0.068953)
# asch                                         Jubi (0.309828)
# peerplays-ppy                            Livecoin (5.622980)
# cloakcoin                                 Bittrex (3.846180)
#
#                                          l3                         l4  \
# bitcoin             Cryptopia (1576.360000)     Poloniex (1693.850000)
# ethereum            Novaexchange (4.258050)          Quoine (9.774240)
# ripple                Mr. Ripple (0.155813)      Mr. Ripple (0.156410)
# litecoin               Cryptopia (6.875950)       Cryptopia (7.068260)
# ethereum-classic        Gatehub (13.779800)      Cryptopia (14.162400)
# dash                 Crypto Dao (16.619400)           COSS (58.573900)
# nem                       HitBTC (0.107727)            COSS (0.107735)
# monero                 Poloniex (30.245600)      BTC Alpha (30.451000)
# iota               IOTA Exchange (0.162569)        Bitfinex (0.163295)
# stratis             SouthXchange (2.945630)        Livecoin (2.995550)
# bitconnect             Livecoin (49.118000)   BCC Exchange (49.595400)
# zcash                  Allcoin (138.778000)  CoinExchange (138.977000)
# bitshares         OpenLedger DEX (0.021624)  OpenLedger DEX (0.033286)
# antshares                Yuanbao (5.150530)            Jubi (5.182980)
# bytecoin-bcn           Cryptopia (0.001071)          HitBTC (0.001101)
# steem                    alcurEX (0.944267)        Livecoin (0.949006)
# qtum                       Yunbi (3.948240)         Yuanbao (3.977600)
# waves                      Tidex (0.909523)           Tidex (1.308420)
# stellar                   Kraken (0.016874)         Yuanbao (0.016923)
# siacoin                 Poloniex (0.006146)         Bittrex (0.006186)
# dogecoin                   C-CEX (0.000021)    Novaexchange (0.000026)
# lisk                    Poloniex (1.354900)            COSS (1.357160)
# byteball               Bittrex (376.704000)     Cryptopia (396.014000)
# factom                Cryptopia (12.830200)        Bittrex (12.834000)
# decred                    YoBit (19.609100)        Bittrex (19.631400)
# komodo                 Cryptopia (0.817483)       Cryptopia (0.880251)
# digibyte            CoinExchange (0.009278)    Novaexchange (0.009576)
# gamecredits         Novaexchange (1.189530)       Cryptopia (1.210280)
# pivx                Novaexchange (0.860509)    Novaexchange (1.135320)
# nxt                     Poloniex (0.067161)        Poloniex (0.067605)
# bancor                      COSS (1.538180)            COSS (1.576680)
# lykke             Lykke Exchange (0.246814)  Lykke Exchange (0.248058)
# chaincoin           Novaexchange (2.398980)       Cryptopia (2.931160)
# bitcoindark           Cryptopia (33.821500)       Poloniex (34.049600)
# leocoin                   LEObit (0.376684)      LEOxChange (0.407612)
# decent                    HitBTC (0.642345)  OpenLedger DEX (0.693895)
# peercoin             247exchange (0.304004)  OpenLedger DEX (0.910871)
# syscoin                  Bittrex (0.067387)        Poloniex (0.067486)
# emercoin                   xBTCe (0.713717)        Livecoin (0.822737)
# nexus                    Bittrex (0.673670)                        ???
# ark                      Bittrex (0.353072)            COSS (0.353191)
# ubiq                   Cryptopia (0.803606)                        ???
# verge               Novaexchange (0.002002)    SouthXchange (0.002062)
# reddcoin               Cryptopia (0.000889)         alcurEX (0.000912)
# namecoin            SouthXchange (1.598710)           YoBit (1.614530)
# monacoin               Bleutrade (0.453201)       Bleutrade (0.453409)
# gulden                   Bittrex (0.069389)           Nocks (0.069675)
# asch                    Biduobao (0.309828)      Crypto Dao (0.594764)
# peerplays-ppy         Crypto Dao (8.326700)                        ???
# cloakcoin              Cryptopia (3.865970)        Livecoin (4.004190)
#
#                                           l5           pd1           pd2  \
# bitcoin               Livecoin (1856.790000)  1.829115e+02  7.698918e+01
# ethereum                  Quoine (10.749300)  6.249908e+06  1.671228e+04
# ripple                    Gatehub (0.157551)  2.418473e+01  1.860495e+01
# litecoin             Novaexchange (7.238380)  4.681899e+07  1.981658e+07
# ethereum-classic         Bittrex (14.275900)  5.753072e+01  2.414632e+01
# dash                    Livecoin (59.264900)  1.045312e+06  4.393298e+03
# nem                      Poloniex (0.107913)  7.981721e+01  7.605479e+00
# monero                  Poloniex (30.741900)  2.879769e+01  1.906637e+01
# iota                                     ???  1.149034e+00  0.000000e+00
# stratis                  Livecoin (3.009800)  1.372214e+02  2.450855e+01
# bitconnect         Novaexchange (127.642000)  1.716539e+02  1.234316e+00
# zcash             Trade Satoshi (148.741000)  2.165386e+02  1.428220e+02
# bitshares          OpenLedger DEX (0.059394)  1.008150e+10  4.306056e+04
# antshares                   19800 (5.299540)  5.510096e+00  2.659288e+00
# bytecoin-bcn               HitBTC (0.001106)  2.655386e+01  2.056882e+01
# steem                      HitBTC (0.951623)  6.523886e+01  6.047104e+01
# qtum                         BTER (3.983510)  1.162106e+01  1.328768e+00
# waves                       Tidex (1.747490)  3.825745e+04  7.144522e+02
# stellar                    Kraken (0.017047)  6.790390e+00  4.858039e+00
# siacoin                    HitBTC (0.006186)  2.469169e+01  3.791957e+00
# dogecoin                Cryptopia (0.000060)  9.941426e+09  2.243366e+07
# lisk                     Poloniex (1.362620)  3.430311e+03  1.097110e+03
# byteball              Cryptopia (456.662000)  5.390594e+01  5.131622e+00
# factom                   alcurEX (13.179900)  2.064859e+02  1.244817e+02
# decred                 Cryptopia (19.808400)  3.711194e+01  1.303875e+01
# komodo                    Bittrex (0.890164)  6.934867e+01  2.595371e+01
# digibyte                 Poloniex (0.009794)  5.743106e+01  1.568818e+01
# gamecredits               Allcoin (1.258920)  1.341655e+03  3.966230e+02
# pivx                    Cryptopia (1.147360)  3.762962e+04  3.475759e+02
# nxt                      Poloniex (0.067621)  1.517205e+02  1.917336e+01
# bancor                      Liqui (1.594450)  7.323036e+01  1.479925e+01
# lykke              Lykke Exchange (0.248180)  5.747303e+00  1.985254e+00
# chaincoin               Cryptopia (3.011390)  5.663219e+03  5.777872e+01
# bitcoindark              Bittrex (34.099800)  7.270333e+01  3.150382e+01
# leocoin                Crypto Dao (0.424424)  1.770700e+02  8.528647e+01
# decent                    Yuanbao (1.041610)  2.238187e+02  6.440019e+01
# peercoin              BX Thailand (1.219270)  7.822218e+02  5.927925e+02
# syscoin                  Livecoin (0.067803)  5.497935e+01  4.928367e+01
# emercoin                 Livecoin (0.826937)  2.633706e+03  1.199760e+02
# nexus                                    ???  7.845523e+00  0.000000e+00
# ark                          COSS (0.353889)  4.076319e+02  3.110315e+01
# ubiq                                     ???  4.016201e+03  0.000000e+00
# verge                     Bittrex (0.002082)  2.163880e+02  1.030669e+02
# reddcoin                  Bittrex (0.000932)  4.854870e+01  3.600550e+01
# namecoin                Cryptopia (1.626320)  1.077741e+03  5.886065e+02
# monacoin                  Bittrex (0.454162)  1.034855e+01  1.823881e+00
# gulden               CoinExchange (0.069726)  1.359278e+02  1.906269e+01
# asch                                     ???  1.208736e+02  0.000000e+00
# peerplays-ppy                            ???  4.946616e+01  0.000000e+00
# cloakcoin              LiteBit.eu (4.038130)  1.402563e+03  1.796645e+02
#
#                            pd3           pd4           pd5
# bitcoin           6.661169e+01  5.190719e+01     37.528207
# ethereum          1.409464e+04  3.992277e+03   3404.563088
# ripple            1.519642e+01  1.456748e+01     12.823149
# litecoin          1.301518e+06  1.153092e+06  20683.794164
# ethereum-classic  1.874338e+01  1.498828e+01     13.825398
# dash              1.161616e+03  2.003505e+02    196.723693
# nem               6.763393e+00  3.681255e+00      2.976472
# monero            9.019824e+00  6.774162e+00      3.615261
# iota              0.000000e+00 -1.135981e+00      0.000000
# stratis           1.434396e+01  1.217573e+01      8.684962
# bitconnect        0.000000e+00 -1.219266e+00    -63.188449
# zcash             8.305063e+01  8.153795e+01     40.311010
# bitshares         1.138230e+03  3.876045e+02    167.286708
# antshares         0.000000e+00 -2.590402e+00     -5.222340
# bytecoin-bcn      3.308487e+00  0.000000e+00     -3.202532
# steem             3.694326e+01  3.027947e+01     26.167610
# qtum              0.000000e+00 -1.311344e+00    -10.411170
# waves             3.219684e+02  1.681532e+02     69.959199
# stellar           3.039588e+00  1.338455e+00      0.247551
# siacoin           1.738395e+00  9.614343e-01      0.641010
# dogecoin          2.613960e+05  1.595541e+05  30827.871419
# lisk              2.611484e+01  1.789325e+01      5.162114
# byteball          0.000000e+00 -4.881141e+00    -35.025248
# factom            2.049617e+01  2.695185e+00     -2.624451
# decred            1.912377e+00  9.887221e-01      0.000000
# komodo            7.678202e+00 -7.130693e+00    -20.605754
# digibyte          8.974470e+00  3.726725e+00      0.809698
# gamecredits       5.957647e+01  8.113825e+00      3.936708
# pivx              1.410934e+02  7.811718e+01     55.341828
# nxt               1.477073e+01  7.411889e+00      5.682440
# bancor            5.712595e+00  2.982850e+00      1.480134
# lykke             5.595307e-01  4.918205e-02     -0.049158
# chaincoin         2.552793e+01  0.000000e+00    -20.336456
# bitcoindark       8.228494e-01  0.000000e+00     -0.816134
# leocoin           4.700040e+01  2.941915e+01     20.333205
# decent            8.025282e+00 -7.429078e+00    -39.172819
# peercoin          5.595209e+02  9.137068e+01     41.463335
# syscoin           4.148290e+00  2.751093e+00      0.000000
# emercoin          4.166680e+01  2.266131e+01     19.872977
# nexus            -7.274778e+00  0.000000e+00      0.000000
# ark               4.548647e-01  1.976268e-01     -0.197237
# ubiq             -9.757058e+01  0.000000e+00      0.000000
# verge             5.481654e+01  3.365376e+01      2.857321
# reddcoin          2.188481e+01  5.868821e+00      2.127717
# namecoin          1.996797e+01  1.051452e+01      5.912736
# monacoin          4.589575e-02 -4.587470e-02     -1.791211
# gulden            6.678426e+00  8.754908e-01      0.000000
# asch              0.000000e+00 -5.472524e+01      0.000000
# peerplays-ppy    -3.309522e+01  0.000000e+00      0.000000
# cloakcoin         1.524683e+02  4.364503e+01     24.653491

# %%
arb_pairs[['h3', 'l3', 'pd3']].round(2)
# Out:
#                                                        h3  \
# bitcoin                               C-CEX (2626.400000)
# ethereum                          EtherDelta (604.415000)
# ripple                                    BTER (0.179491)
# litecoin                      Novaexchange (89498.600000)
# ethereum-classic                  BTC Markets (16.362600)
# dash                            Bittylicious (209.673000)
# nem                                       Zaif (0.115013)
# monero                              Bitsquare (32.973700)
# iota                             IOTA Exchange (0.162569)
# stratis                           Bittylicious (3.368150)
# bitconnect                           Livecoin (49.118000)
# zcash                                Bitlish (254.034000)
# bitshares                                YoBit (0.267750)
# antshares                              Yuanbao (5.150530)
# bytecoin-bcn                            HitBTC (0.001106)
# steem                           OpenLedger DEX (1.293110)
# qtum                                     Yunbi (3.948240)
# waves             Waves Decentralized Exchange (3.837900)
# stellar                      Bitcoin Indonesia (0.017387)
# siacoin                                Bittrex (0.006253)
# dogecoin                         Trade Satoshi (0.053992)
# lisk                                    BitBay (1.708730)
# byteball                             Bittrex (376.704000)
# factom                              BTC Alpha (15.459900)
# decred                               Poloniex (19.984100)
# komodo                               Cryptopia (0.880251)
# digibyte                                 YoBit (0.010111)
# gamecredits                     OpenLedger DEX (1.898210)
# pivx                                  Livecoin (2.074630)
# nxt                               SouthXchange (0.077081)
# bancor                                 Bittrex (1.626050)
# lykke                           Lykke Exchange (0.248195)
# chaincoin                            Cryptopia (3.011390)
# bitcoindark                           Bittrex (34.099800)
# leocoin                               Livecoin (0.553727)
# decent                          OpenLedger DEX (0.693895)
# peercoin                        OpenLedger DEX (2.004970)
# syscoin                           Novaexchange (0.070182)
# emercoin                          Tux Exchange (1.011100)
# nexus                                Cryptopia (0.624662)
# ark                                  Cryptopia (0.354678)
# ubiq                                 Cryptopia (0.019523)
# verge                                    C-CEX (0.003100)
# reddcoin                          Novaexchange (0.001084)
# namecoin                        Altcoin Trader (1.917940)
# monacoin                             Bleutrade (0.453409)
# gulden                              LiteBit.eu (0.074023)
# asch                                  Biduobao (0.309828)
# peerplays-ppy                         Livecoin (5.570960)
# cloakcoin                            Cryptopia (9.760350)
#
#                                          l3         pd3
# bitcoin             Cryptopia (1576.360000)       66.61
# ethereum            Novaexchange (4.258050)    14094.64
# ripple                Mr. Ripple (0.155813)       15.20
# litecoin               Cryptopia (6.875950)  1301517.96
# ethereum-classic        Gatehub (13.779800)       18.74
# dash                 Crypto Dao (16.619400)     1161.62
# nem                       HitBTC (0.107727)        6.76
# monero                 Poloniex (30.245600)        9.02
# iota               IOTA Exchange (0.162569)        0.00
# stratis             SouthXchange (2.945630)       14.34
# bitconnect             Livecoin (49.118000)        0.00
# zcash                  Allcoin (138.778000)       83.05
# bitshares         OpenLedger DEX (0.021624)     1138.23
# antshares                Yuanbao (5.150530)        0.00
# bytecoin-bcn           Cryptopia (0.001071)        3.31
# steem                    alcurEX (0.944267)       36.94
# qtum                       Yunbi (3.948240)        0.00
# waves                      Tidex (0.909523)      321.97
# stellar                   Kraken (0.016874)        3.04
# siacoin                 Poloniex (0.006146)        1.74
# dogecoin                   C-CEX (0.000021)   261395.99
# lisk                    Poloniex (1.354900)       26.11
# byteball               Bittrex (376.704000)        0.00
# factom                Cryptopia (12.830200)       20.50
# decred                    YoBit (19.609100)        1.91
# komodo                 Cryptopia (0.817483)        7.68
# digibyte            CoinExchange (0.009278)        8.97
# gamecredits         Novaexchange (1.189530)       59.58
# pivx                Novaexchange (0.860509)      141.09
# nxt                     Poloniex (0.067161)       14.77
# bancor                      COSS (1.538180)        5.71
# lykke             Lykke Exchange (0.246814)        0.56
# chaincoin           Novaexchange (2.398980)       25.53
# bitcoindark           Cryptopia (33.821500)        0.82
# leocoin                   LEObit (0.376684)       47.00
# decent                    HitBTC (0.642345)        8.03
# peercoin             247exchange (0.304004)      559.52
# syscoin                  Bittrex (0.067387)        4.15
# emercoin                   xBTCe (0.713717)       41.67
# nexus                    Bittrex (0.673670)       -7.27
# ark                      Bittrex (0.353072)        0.45
# ubiq                   Cryptopia (0.803606)      -97.57
# verge               Novaexchange (0.002002)       54.82
# reddcoin               Cryptopia (0.000889)       21.88
# namecoin            SouthXchange (1.598710)       19.97
# monacoin               Bleutrade (0.453201)        0.05
# gulden                   Bittrex (0.069389)        6.68
# asch                    Biduobao (0.309828)        0.00
# peerplays-ppy         Crypto Dao (8.326700)      -33.10
# cloakcoin              Cryptopia (3.865970)      152.47
