# %%
import requests
import re
import pandas as pd
import time
from bs4 import BeautifulSoup

# %% [markdown]
# # Get all the symbols

# %%
response = requests.get("https://coinmarketcap.com/currencies/")
soup = BeautifulSoup(response.text, 'html.parser')

# %%
main_table = [t for t in soup.find_all('table') if t.has_attr('id') and t['id'] == 'currencies']
assert len(main_table) == 1, "Only one main table"
main_table = main_table[0]

# %%
coins = [t for t in main_table.find_all('tr') if t.has_attr('id')]
coin_aliases = [re.search("\/currencies\/(.*)\/", t.find_all('a')[0]['href']).group(1) for t in coins]
coin_aliases
# Out:
# ['bitcoin',
#  'ethereum',
#  'ripple',
#  'litecoin',
#  'ethereum-classic',
#  'dash',
#  'nem',
#  'monero',
#  'iota',
#  'bitconnect',
#  'stratis',
#  'zcash',
#  'bitshares',
#  'bytecoin-bcn',
#  'antshares',
#  'steem',
#  'waves',
#  'qtum',
#  'siacoin',
#  'dogecoin',
#  'stellar',
#  'byteball',
#  'lisk',
#  'factom',
#  'decred',
#  'digibyte',
#  'gamecredits',
#  'pivx',
#  'komodo',
#  'bancor',
#  'nxt',
#  'chaincoin',
#  'bitcoindark',
#  'leocoin',
#  'lykke',
#  'decent',
#  'peercoin',
#  'ark',
#  'syscoin',
#  'emercoin',
#  'nexus',
#  'verge',
#  'reddcoin',
#  'ubiq',
#  'asch',
#  'namecoin',
#  'peerplays-ppy',
#  'gulden',
#  'monacoin',
#  'cloakcoin',
#  'daxxcoin',
#  'counterparty',
#  'dubaicoin-dbix',
#  'library-credit',
#  'omni',
#  'e-dinar-coin',
#  'skycoin',
#  'sibcoin',
#  'bitbay',
#  'blocknet',
#  'ybcoin',
#  'potcoin',
#  'crown',
#  'zcoin',
#  'viacoin',
#  'groestlcoin',
#  'elastic',
#  'blackcoin',
#  'burst',
#  'mooncoin',
#  'iocoin',
#  'golos',
#  'vertcoin',
#  'faircoin',
#  'firstcoin',
#  'voxels',
#  'novacoin',
#  'mysterium',
#  'salus',
#  'monetaryunit',
#  'nav-coin',
#  'digitalnote',
#  'ion',
#  'e-coin',
#  'gridcoin',
#  'earthcoin',
#  'expanse',
#  'neoscoin',
#  'luckchain',
#  'rubycoin',
#  'bitcoin-plus',
#  'xtrabytes',
#  'energycoin',
#  'shift',
#  'dnotes',
#  'feathercoin',
#  'bitsend',
#  'radium',
#  'spreadcoin',
#  'heat-ledger']

# %% [markdown]
# # Get all the market prices

# %%
def get_pair_info(tr_text):
    """
    Get pair info from html text of <tr>
    """
    tds = tr_text.find_all('td')
    exchange = tds[1].text
    pair = tds[2].text
    volume = float(tds[3].find('span')['data-usd']) if tds[3].find('span')['data-usd'] != '?' else 0
    price = float(tds[4].find('span')['data-usd']) if tds[4].find('span')['data-usd'] != '?' else 0
    share = float(tds[5].text[0:-1])
    time = tds[6].text

    return exchange, pair, volume, price, share, time

# %%
def get_arb_prices(coin_alias, tail_num=5):
    """
    Get the highest and lowest 5 prices among all exchanges.
    """
    # Get the market html
    coin_market_ret = requests.get("https://coinmarketcap.com/currencies/%s/#markets" % coin_alias)
    assert coin_market_ret.status_code == 200, "Status code (%d) is not 200.\n%s" % (coin_market_ret.status_code, coin_market_ret.text)
    coin_market_soup = BeautifulSoup(coin_market_ret.text, 'html.parser')
    coin_table = [t for t in coin_market_soup.find_all('table') if t.has_attr('id') and t['id'] == 'markets-table']
    assert len(coin_table) == 1, "Only one main table"
    coin_table = coin_table[0]
    # Get all the records
    coin_records = coin_table.find_all('tr')
    records = pd.DataFrame(columns=['exchange', 'pair', 'volume', 'price', 'share', 'last_updated'],
                           data=[get_pair_info(t) for t in coin_records 
                                 if len(t.find_all('td')) > 0])
    # Take only recent records
    records = records[(records['last_updated'] == "Recently") & (records['price'] > 0)]
    # Get the lowest and highest records
    lowest = records.sort_values("price").head(tail_num).apply(lambda x: "%s (%.6f)" % (x["exchange"], x["price"]), axis=1)
    highest = records.sort_values("price", ascending=False).head(tail_num).apply(lambda x: "%s (%.6f)" % (x["exchange"], x["price"]), axis=1)
    return highest, lowest

# %%
level = 3
arb_pairs = pd.DataFrame(columns=["h%d" % (t+1) for t in range(0,level)]+["l%d" % (t+1) for t in range(0,level)])
for coin_alias in coin_aliases[0:50]:
    highest, lowest = get_arb_prices(coin_alias)
    highest = (highest.tolist() + ['???'] * level)[0:level]
    lowest = (lowest.tolist() + ['???'] * level)[0:level]
    arb_pairs.loc[coin_alias] = highest + lowest
    time.sleep(5)
arb_pairs
# Out:
#                                            h1  \
# bitcoin               Cryptopia (2784.780000)
# ethereum           Decentrex (1170520.000000)
# ripple                  Cryptomate (0.204617)
# litecoin           Cryptopia (4178130.000000)
# ethereum-classic     CoinExchange (20.367800)
# dash               Novaexchange (4019.090000)
# nem                      Cryptopia (0.190386)
# monero                 Cryptomate (37.752500)
# iota                 IOTA Exchange (0.174610)
# bitconnect          Novaexchange (139.575000)
# stratis                  Cryptopia (5.013260)
# zcash                LocalTrade (1677.960000)
# bitshares         OpenLedger DEX (152.550000)
# bytecoin-bcn              Poloniex (0.001448)
# antshares                    19800 (5.501660)
# steem               OpenLedger DEX (1.512000)
# waves                        Tidex (4.412700)
# qtum                       Allcoin (4.493010)
# siacoin                  Cryptopia (0.008018)
# dogecoin               Cryptopia (111.396000)
# stellar                  RippleFox (0.016793)
# byteball               Cryptopia (548.888000)
# lisk                OpenLedger DEX (2.592460)
# factom                  Cryptopia (40.596800)
# decred                  Cryptopia (39.581900)
# digibyte                    EmpoEx (0.014906)
# gamecredits         OpenLedger DEX (7.340170)
# pivx                     Livecoin (10.837300)
# komodo                CoinExchange (1.165580)
# bancor                  EtherDelta (1.999670)
# nxt                          C-CEX (0.165000)
# chaincoin             Novaexchange (3.936980)
# bitcoindark             Cryptopia (59.592200)
# leocoin              Trade Satoshi (0.935589)
# lykke               Lykke Exchange (0.267470)
# decent                       Liqui (2.127240)
# peercoin                     USD X (2.529330)
# ark                      Cryptopia (1.055110)
# syscoin                     EmpoEx (0.106222)
# emercoin           OpenLedger DEX (18.395600)
# nexus                    Cryptopia (0.659578)
# verge                 Novaexchange (0.005647)
# reddcoin             Trade Satoshi (0.001168)
# ubiq                     Cryptopia (0.802134)
# asch                    Crypto Dao (0.638816)
# namecoin              Bittylicious (2.605990)
# peerplays-ppy             Livecoin (9.000000)
# gulden                       YoBit (0.164739)
# monacoin                      Zaif (0.460890)
# cloakcoin                Mercatox (61.065400)
#
#                                                        h2  \
# bitcoin                             Bittrex (2679.840000)
# ethereum                          Livecoin (24787.200000)
# ripple                                  Rippex (0.198937)
# litecoin                      CoinGather (1193750.000000)
# ethereum-classic                        C-CEX (18.950000)
# dash                           Novaexchange (1392.610000)
# nem                                  Cryptopia (0.125461)
# monero                              Cryptopia (36.342700)
# iota                                  Bitfinex (0.161823)
# bitconnect                           Livecoin (53.388900)
# stratis                           Bittylicious (4.242920)
# zcash                                  USD X (317.235000)
# bitshares                       OpenLedger DEX (3.293670)
# bytecoin-bcn                           alcurEX (0.001427)
# antshares                                 Jubi (5.458880)
# steem                           OpenLedger DEX (1.509660)
# waves             Waves Decentralized Exchange (4.105290)
# qtum                                      BTER (4.278580)
# siacoin                                Bittrex (0.007126)
# dogecoin                          Novaexchange (0.079337)
# stellar                                  BTC38 (0.016303)
# byteball                             Cryptox (438.654000)
# lisk                                    HitBTC (1.898640)
# factom                              Cryptopia (31.365100)
# decred                              Cryptopia (25.487100)
# digibyte                          CoinExchange (0.011818)
# gamecredits                     OpenLedger DEX (5.000000)
# pivx                              CoinExchange (4.258070)
# komodo                               Cryptopia (0.813000)
# bancor                                    COSS (1.954120)
# nxt                         Nxt Asset Exchange (0.087329)
# chaincoin                            Cryptopia (3.105660)
# bitcoindark                         Bleutrade (48.616000)
# leocoin                             LEOxChange (0.536914)
# lykke                           Lykke Exchange (0.267230)
# decent                                 Yuanbao (1.108000)
# peercoin                          Bittylicious (2.026910)
# ark                                 LiteBit.eu (0.447745)
# syscoin                           Bittylicious (0.102930)
# emercoin                                 USD X (1.545870)
# nexus                                  Bittrex (0.645801)
# verge                               CoinGather (0.004232)
# reddcoin                             Cryptopia (0.001098)
# ubiq                                 Cryptopia (0.797531)
# asch                                  Biduobao (0.372974)
# namecoin                        Altcoin Trader (2.302450)
# peerplays-ppy                         Livecoin (8.138980)
# gulden                            Novaexchange (0.087956)
# monacoin                              Livecoin (0.440500)
# cloakcoin                           Cryptopia (11.762300)
#
#                                          h3                            l1  \
# bitcoin                  Luno (2545.400000)       LocalTrade (215.452000)
# ethereum           LocalTrade (1856.830000)  CryptoDerivatives (4.649300)
# ripple               BTC Markets (0.195725)         Mr. Ripple (0.164611)
# litecoin          Novaexchange (640.551000)       Novaexchange (1.540910)
# ethereum-classic     Cryptomate (18.147400)      CoinExchange (13.331200)
# dash                LocalTrade (546.953000)     OpenLedger DEX (0.122324)
# nem                   LiteBit.eu (0.122334)               BTER (0.105511)
# monero                 Poloniex (35.176600)          Poloniex (30.023900)
# iota                    Bitfinex (0.161727)           Bitfinex (0.160470)
# bitconnect         BCC Exchange (53.377800)      Novaexchange (52.638500)
# stratis             SouthXchange (3.603900)           Livecoin (2.600000)
# zcash             CoinExchange (298.050000)         Mercatox (127.764000)
# bitshares                  YoBit (0.298114)     OpenLedger DEX (0.000001)
# bytecoin-bcn            Poloniex (0.001425)          Cryptopia (0.001192)
# antshares                Yuanbao (5.458880)              Yunbi (5.352500)
# steem             OpenLedger DEX (1.293550)           Poloniex (0.997530)
# waves             OpenLedger DEX (4.036700)              Tidex (0.015624)
# qtum                       Yunbi (4.263830)               BTER (4.056480)
# siacoin                Cryptopia (0.007057)            alcurEX (0.006495)
# dogecoin           Trade Satoshi (0.066714)       Novaexchange (0.000001)
# stellar                  Bittrex (0.016226)            alcurEX (0.015438)
# byteball               Bittrex (438.318000)        Cryptopia (284.178000)
# lisk                    Livecoin (1.668250)     OpenLedger DEX (0.061774)
# factom                BTC Alpha (16.604900)           Yuanbao (13.588200)
# decred                Bleutrade (23.525400)             YoBit (18.951500)
# digibyte              LiteBit.eu (0.010678)          Cryptopia (0.009062)
# gamecredits       OpenLedger DEX (2.038800)       Novaexchange (0.556747)
# pivx                    Livecoin (3.798990)           Livecoin (0.513589)
# komodo                   Bittrex (0.805185)       CoinExchange (0.761780)
# bancor                   Bittrex (1.922500)             HitBTC (1.771650)
# nxt                 SouthXchange (0.082791)              C-CEX (0.063328)
# chaincoin              Cryptopia (3.100450)          Cryptopia (2.735040)
# bitcoindark            Poloniex (37.532600)           Bittrex (36.004800)
# leocoin                    C-CEX (0.532304)         LEOxChange (0.320000)
# lykke             Lykke Exchange (0.265795)     Lykke Exchange (0.260298)
# decent                    HitBTC (0.800650)     OpenLedger DEX (0.611620)
# peercoin          OpenLedger DEX (2.008540)        247exchange (0.286700)
# ark                      Bittrex (0.422321)          Cryptopia (0.200029)
# syscoin             Novaexchange (0.075190)              YoBit (0.070093)
# emercoin            Tux Exchange (1.083250)          Cryptopia (0.728842)
# nexus                  Cryptopia (0.568369)          Cryptopia (0.568369)
# verge               Novaexchange (0.003450)          Cryptopia (0.002187)
# reddcoin               Cryptopia (0.001062)      Trade Satoshi (0.000900)
# ubiq                     Bittrex (0.721528)            Bittrex (0.721528)
# asch                        Jubi (0.371646)            Yuanbao (0.332220)
# namecoin            Tux Exchange (2.018350)        247exchange (0.305200)
# peerplays-ppy           Livecoin (7.225900)         Crypto Dao (6.372050)
# gulden                LiteBit.eu (0.075095)          Bleutrade (0.069006)
# monacoin               Bleutrade (0.423253)            Bittrex (0.400143)
# cloakcoin                  YoBit (6.162260)           Livecoin (4.000100)
#
#                                           l2  \
# bitcoin              LocalTrade (218.400000)
# ethereum                   Quoine (9.774240)
# ripple                 Mr. Ripple (0.164835)
# litecoin                Cryptopia (2.901570)
# ethereum-classic    CoinExchange (14.916400)
# dash               OpenLedger DEX (4.937730)
# nem                          BTER (0.110284)
# monero                 BTC Alpha (32.706400)
# iota                     Bitfinex (0.161727)
# bitconnect          CoinExchange (53.201900)
# stratis                  Livecoin (2.875840)
# zcash                   Allcoin (149.057000)
# bitshares          OpenLedger DEX (0.005113)
# bytecoin-bcn            Cryptopia (0.001208)
# antshares                 Bittrex (5.401340)
# steem                    Poloniex (1.009350)
# waves                       Tidex (0.520408)
# qtum                      Yuanbao (4.232840)
# siacoin                  Poloniex (0.006708)
# dogecoin             Novaexchange (0.000015)
# stellar                   Yuanbao (0.015639)
# byteball              Cryptopia (434.395000)
# lisk               OpenLedger DEX (0.170350)
# factom                   alcurEX (13.666500)
# decred                 Bleutrade (20.448000)
# digibyte                Cryptopia (0.009723)
# gamecredits             Cryptopia (1.100920)
# pivx                    Cryptopia (0.588658)
# komodo                  Cryptopia (0.775474)
# bancor                      Liqui (1.860630)
# nxt               Stocks.Exchange (0.064182)
# chaincoin               Cryptopia (3.066320)
# bitcoindark             Poloniex (36.781400)
# leocoin                    LEObit (0.404584)
# lykke              Lykke Exchange (0.260363)
# decent                    Bittrex (0.675016)
# peercoin              247exchange (0.292571)
# ark                     Cryptopia (0.312083)
# syscoin                  Livecoin (0.070305)
# emercoin                Cryptopia (0.806425)
# nexus                     Bittrex (0.645801)
# verge                       C-CEX (0.002188)
# reddcoin                Cryptopia (0.001001)
# ubiq                    Cryptopia (0.797531)
# asch                         Jubi (0.371646)
# namecoin              247exchange (0.378444)
# peerplays-ppy            Livecoin (7.225900)
# gulden                  Bleutrade (0.070093)
# monacoin                Bleutrade (0.417170)
# cloakcoin                Livecoin (4.076710)
#
#                                                           l3
# bitcoin           Bitcoin Growth Fund Exchange (1669.730000)
# ethereum                                  Quoine (10.730000)
# ripple                  Bitstamp (Ripple Gateway) (0.169905)
# litecoin                               DCExchange (4.250000)
# ethereum-classic                          HitBTC (15.426000)
# dash                                  Crypto Dao (17.766900)
# nem                                     Cryptopia (0.112027)
# monero                                      BTER (32.814700)
# iota                                     Bitfinex (0.161823)
# bitconnect                          BCC Exchange (53.377800)
# stratis                              SouthXchange (2.991040)
# zcash                                 Cryptopia (159.777000)
# bitshares                          OpenLedger DEX (0.023434)
# bytecoin-bcn                               HitBTC (0.001258)
# antshares                                    Jubi (5.458880)
# steem                                    Livecoin (1.012570)
# waves                                       Tidex (0.899393)
# qtum                                        Yunbi (4.263830)
# siacoin                                   Bittrex (0.006708)
# dogecoin                                    C-CEX (0.000019)
# stellar                                 RippleFox (0.015823)
# byteball                                Bittrex (438.318000)
# lisk                                     Livecoin (1.499580)
# factom                                  Poloniex (14.046700)
# decred                                  Poloniex (20.999700)
# digibyte                             Novaexchange (0.009880)
# gamecredits                             Cryptopia (1.218400)
# pivx                                 Novaexchange (0.940954)
# komodo                                  Cryptopia (0.784129)
# bancor                                      Liqui (1.889490)
# nxt                            Nxt Asset Exchange (0.066351)
# chaincoin                               Cryptopia (3.100450)
# bitcoindark                            Cryptopia (36.906900)
# leocoin                                LEOxChange (0.425920)
# lykke                              Lykke Exchange (0.264800)
# decent                             OpenLedger DEX (0.745289)
# peercoin                              247exchange (0.307782)
# ark                                     Cryptopia (0.400069)
# syscoin                                   Bittrex (0.070687)
# emercoin                                    YoBit (0.808761)
# nexus                                   Cryptopia (0.659578)
# verge                                SouthXchange (0.002188)
# reddcoin                                Bleutrade (0.001004)
# ubiq                                    Cryptopia (0.802134)
# asch                                     Biduobao (0.372974)
# namecoin                                Bleutrade (1.700330)
# peerplays-ppy                            Livecoin (8.138980)
# gulden                                    Bittrex (0.070815)
# monacoin                                     Zaif (0.417595)
# cloakcoin                               Cryptopia (4.117960)

# %%
arb_pairs[['h3', 'l3']]
# Out:
#                                          h3  \
# bitcoin                  Luno (2545.400000)
# ethereum           LocalTrade (1856.830000)
# ripple               BTC Markets (0.195725)
# litecoin          Novaexchange (640.551000)
# ethereum-classic     Cryptomate (18.147400)
# dash                LocalTrade (546.953000)
# nem                   LiteBit.eu (0.122334)
# monero                 Poloniex (35.176600)
# iota                    Bitfinex (0.161727)
# bitconnect         BCC Exchange (53.377800)
# stratis             SouthXchange (3.603900)
# zcash             CoinExchange (298.050000)
# bitshares                  YoBit (0.298114)
# bytecoin-bcn            Poloniex (0.001425)
# antshares                Yuanbao (5.458880)
# steem             OpenLedger DEX (1.293550)
# waves             OpenLedger DEX (4.036700)
# qtum                       Yunbi (4.263830)
# siacoin                Cryptopia (0.007057)
# dogecoin           Trade Satoshi (0.066714)
# stellar                  Bittrex (0.016226)
# byteball               Bittrex (438.318000)
# lisk                    Livecoin (1.668250)
# factom                BTC Alpha (16.604900)
# decred                Bleutrade (23.525400)
# digibyte              LiteBit.eu (0.010678)
# gamecredits       OpenLedger DEX (2.038800)
# pivx                    Livecoin (3.798990)
# komodo                   Bittrex (0.805185)
# bancor                   Bittrex (1.922500)
# nxt                 SouthXchange (0.082791)
# chaincoin              Cryptopia (3.100450)
# bitcoindark            Poloniex (37.532600)
# leocoin                    C-CEX (0.532304)
# lykke             Lykke Exchange (0.265795)
# decent                    HitBTC (0.800650)
# peercoin          OpenLedger DEX (2.008540)
# ark                      Bittrex (0.422321)
# syscoin             Novaexchange (0.075190)
# emercoin            Tux Exchange (1.083250)
# nexus                  Cryptopia (0.568369)
# verge               Novaexchange (0.003450)
# reddcoin               Cryptopia (0.001062)
# ubiq                     Bittrex (0.721528)
# asch                        Jubi (0.371646)
# namecoin            Tux Exchange (2.018350)
# peerplays-ppy           Livecoin (7.225900)
# gulden                LiteBit.eu (0.075095)
# monacoin               Bleutrade (0.423253)
# cloakcoin                  YoBit (6.162260)
#
#                                                           l3
# bitcoin           Bitcoin Growth Fund Exchange (1669.730000)
# ethereum                                  Quoine (10.730000)
# ripple                  Bitstamp (Ripple Gateway) (0.169905)
# litecoin                               DCExchange (4.250000)
# ethereum-classic                          HitBTC (15.426000)
# dash                                  Crypto Dao (17.766900)
# nem                                     Cryptopia (0.112027)
# monero                                      BTER (32.814700)
# iota                                     Bitfinex (0.161823)
# bitconnect                          BCC Exchange (53.377800)
# stratis                              SouthXchange (2.991040)
# zcash                                 Cryptopia (159.777000)
# bitshares                          OpenLedger DEX (0.023434)
# bytecoin-bcn                               HitBTC (0.001258)
# antshares                                    Jubi (5.458880)
# steem                                    Livecoin (1.012570)
# waves                                       Tidex (0.899393)
# qtum                                        Yunbi (4.263830)
# siacoin                                   Bittrex (0.006708)
# dogecoin                                    C-CEX (0.000019)
# stellar                                 RippleFox (0.015823)
# byteball                                Bittrex (438.318000)
# lisk                                     Livecoin (1.499580)
# factom                                  Poloniex (14.046700)
# decred                                  Poloniex (20.999700)
# digibyte                             Novaexchange (0.009880)
# gamecredits                             Cryptopia (1.218400)
# pivx                                 Novaexchange (0.940954)
# komodo                                  Cryptopia (0.784129)
# bancor                                      Liqui (1.889490)
# nxt                            Nxt Asset Exchange (0.066351)
# chaincoin                               Cryptopia (3.100450)
# bitcoindark                            Cryptopia (36.906900)
# leocoin                                LEOxChange (0.425920)
# lykke                              Lykke Exchange (0.264800)
# decent                             OpenLedger DEX (0.745289)
# peercoin                              247exchange (0.307782)
# ark                                     Cryptopia (0.400069)
# syscoin                                   Bittrex (0.070687)
# emercoin                                    YoBit (0.808761)
# nexus                                   Cryptopia (0.659578)
# verge                                SouthXchange (0.002188)
# reddcoin                                Bleutrade (0.001004)
# ubiq                                    Cryptopia (0.802134)
# asch                                     Biduobao (0.372974)
# namecoin                                Bleutrade (1.700330)
# peerplays-ppy                            Livecoin (8.138980)
# gulden                                    Bittrex (0.070815)
# monacoin                                     Zaif (0.417595)
# cloakcoin                               Cryptopia (4.117960)
